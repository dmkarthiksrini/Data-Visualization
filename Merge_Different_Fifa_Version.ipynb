# %%
import pandas as pd

# %%
df_15 = pd.read_csv("players_15.csv")

# %%
df_16 = pd.read_csv("players_16.csv")

# %%
df_17 = pd.read_csv("players_17.csv")

# %%
df_18 = pd.read_csv("players_18.csv")

# %%
df_19 = pd.read_csv("players_19.csv")

# %%
df_20 = pd.read_csv("players_20.csv")

# %%
df_15
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2           9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3          41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4         167495  https://sofifa.com/player/167495/manuel-neuer/...
# ...          ...                                                ...
# 15460     220806  https://sofifa.com/player/220806/ellis-redman/...
# 15461     225509  https://sofifa.com/player/225509/aaron-collins...
# 15462     217591  https://sofifa.com/player/217591/piotr-zemlo/1...
# 15463     222947  https://sofifa.com/player/222947/tom-davies/15...
# 15464     201197  https://sofifa.com/player/201197/paul-tisdale/...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   27
# ...

# %%
df_15['Fifa_Version'] = 15

# %%
df_15
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2           9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3          41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4         167495  https://sofifa.com/player/167495/manuel-neuer/...
# ...          ...                                                ...
# 15460     220806  https://sofifa.com/player/220806/ellis-redman/...
# 15461     225509  https://sofifa.com/player/225509/aaron-collins...
# 15462     217591  https://sofifa.com/player/217591/piotr-zemlo/1...
# 15463     222947  https://sofifa.com/player/222947/tom-davies/15...
# 15464     201197  https://sofifa.com/player/201197/paul-tisdale/...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   27
# ...

# %%
df_16['Fifa_Version'] = 16

# %%
df_17['Fifa_Version'] = 17

# %%
df_18['Fifa_Version'] = 18

# %%
df_19['Fifa_Version'] = 19

# %%
df_20['Fifa_Version'] = 20

# %%
#df = pd.merge(df_15, df_16, how='outer')

#df = df_15.merge(df_16,how ='outer').merge(df_17,how ='outer').merge(df_18,how ='outer').merge(df_19,how ='outer').merge(df_20,how ='outer')


df = pd.merge(df_15, df_16, how='outer')

# %%
df
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2           9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3          41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4         167495  https://sofifa.com/player/167495/manuel-neuer/...
# ...          ...                                                ...
# 30341     224867  https://sofifa.com/player/224867/ryan-horne/16...
# 30342     229852  https://sofifa.com/player/229852/corey-shephar...
# 30343     227910  https://sofifa.com/player/227910/liam-gooch/16...
# 30344     225339  https://sofifa.com/player/225339/sam-warburton...
# 30345      11728  https://sofifa.com/player/11728/barry-richards...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   27
# ...

# %%
df_15
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2           9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3          41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4         167495  https://sofifa.com/player/167495/manuel-neuer/...
# ...          ...                                                ...
# 15460     220806  https://sofifa.com/player/220806/ellis-redman/...
# 15461     225509  https://sofifa.com/player/225509/aaron-collins...
# 15462     217591  https://sofifa.com/player/217591/piotr-zemlo/1...
# 15463     222947  https://sofifa.com/player/222947/tom-davies/15...
# 15464     201197  https://sofifa.com/player/201197/paul-tisdale/...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   27
# ...

# %%
df_16
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2           9014  https://sofifa.com/player/9014/arjen-robben/16...
# 3         167495  https://sofifa.com/player/167495/manuel-neuer/...
# 4         176580  https://sofifa.com/player/176580/luis-suarez/1...
# ...          ...                                                ...
# 14876     224867  https://sofifa.com/player/224867/ryan-horne/16...
# 14877     229852  https://sofifa.com/player/229852/corey-shephar...
# 14878     227910  https://sofifa.com/player/227910/liam-gooch/16...
# 14879     225339  https://sofifa.com/player/225339/sam-warburton...
# 14880      11728  https://sofifa.com/player/11728/barry-richards...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   28
# ...

# %%
df_1 = pd.merge(df, df_17, how='outer')

# %%
df_2 = pd.concat([df_1, df_18], join="outer")

# %%
df_2
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2           9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3          41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4         167495  https://sofifa.com/player/167495/manuel-neuer/...
# ...          ...                                                ...
# 17587     237463  https://sofifa.com/player/237463/adam-kelsey/1...
# 17588     231381  https://sofifa.com/player/231381/jordan-young/...
# 17589     240404  https://sofifa.com/player/240404/jack-keeble/1...
# 17590      11728  https://sofifa.com/player/11728/barry-richards...
# 17591     235352  https://sofifa.com/player/235352/tommy-kassemo...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   27
# ...

# %%
df_17
# Out:
#        sofifa_id                                         player_url  \
# 0          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 1         158023  https://sofifa.com/player/158023/lionel-messi/...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         167495  https://sofifa.com/player/167495/manuel-neuer/...
# 4         176580  https://sofifa.com/player/176580/luis-suarez/1...
# ...          ...                                                ...
# 17004     227986  https://sofifa.com/player/227986/tommy-ouldrid...
# 17005     212270  https://sofifa.com/player/212270/mark-foden/17...
# 17006     223621  https://sofifa.com/player/223621/dean-mahon/17...
# 17007     228581  https://sofifa.com/player/228581/ben-kelly/17/...
# 17008      11728  https://sofifa.com/player/11728/barry-richards...
#
#               short_name                            long_name  age  \
# 0      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   31
# ...

# %%
df_18
# Out:
#        sofifa_id                                         player_url  \
# 0          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 1         158023  https://sofifa.com/player/158023/lionel-messi/...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         167495  https://sofifa.com/player/167495/manuel-neuer/...
# 4         176580  https://sofifa.com/player/176580/luis-suarez/1...
# ...          ...                                                ...
# 17587     237463  https://sofifa.com/player/237463/adam-kelsey/1...
# 17588     231381  https://sofifa.com/player/231381/jordan-young/...
# 17589     240404  https://sofifa.com/player/240404/jack-keeble/1...
# 17590      11728  https://sofifa.com/player/11728/barry-richards...
# 17591     235352  https://sofifa.com/player/235352/tommy-kassemo...
#
#               short_name                            long_name  age  \
# 0      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   32
# ...

# %%
df_3 = pd.concat([df_2, df_19], join="outer")

# %%
df_4 = pd.concat([df_3, df_20], join="outer")

# %%
df_4
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2           9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3          41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4         167495  https://sofifa.com/player/167495/manuel-neuer/...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   27
# ...

# %%
df_19
# Out:
#        sofifa_id                                         player_url  \
# 0          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 1         158023  https://sofifa.com/player/158023/lionel-messi/...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         193080  https://sofifa.com/player/193080/david-de-gea-...
# 4         192985  https://sofifa.com/player/192985/kevin-de-bruy...
# ...          ...                                                ...
# 17765     238985  https://sofifa.com/player/238985/pierce-philli...
# 17766     240160  https://sofifa.com/player/240160/alexander-kal...
# 17767     241304  https://sofifa.com/player/241304/junliang-ma/1...
# 17768     240158  https://sofifa.com/player/240158/christoph-ehl...
# 17769     243961  https://sofifa.com/player/243961/evan-tweed/19...
#
#               short_name                            long_name  age  \
# 0      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   33
# ...

# %%
df_20
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32
# ...

# %%
df_4['sofifa_id']
# Out:
# 0        158023
# 1         20801
# 2          9014
# 3         41236
# 4        167495
#           ...
# 18273    245006
# 18274    250995
# 18275    252332
# 18276    251110
# 18277    233449
# Name: sofifa_id, Length: 100995, dtype: int64

# %%
df_4.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club',
#        ...
#        'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb',
#        'Fifa_Version'],
#       dtype='object', length=105)

# %%
df_4.sort_values('sofifa_id')
# Out:
#        sofifa_id                                         player_url  \
# 20173          2  https://sofifa.com/player/2/giovanni-pasquale/...
# 4325           2  https://sofifa.com/player/2/giovanni-pasquale/...
# 1345         164  https://sofifa.com/player/164/giampiero-pinzi/...
# 33227        164  https://sofifa.com/player/164/giampiero-pinzi/...
# 5143         164  https://sofifa.com/player/164/giampiero-pinzi/...
# ...          ...                                                ...
# 16668     252900  https://sofifa.com/player/252900/markus-fjorto...
# 16830     252901  https://sofifa.com/player/252901/claudiu-borto...
# 14051     252903  https://sofifa.com/player/252903/shinta-appelk...
# 15086     252904  https://sofifa.com/player/252904/marcel-langer...
# 15893     252905  https://sofifa.com/player/252905/lino-kasten/2...
#
#           short_name           long_name  age         dob  height_cm  \
# 20173    G. Pasquale  Giovanni  Pasquale   33  1982-01-05        182
# ...

# %%
df_4.to_csv("Data_Visualization_DataSet.csv")
